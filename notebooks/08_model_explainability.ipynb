# %% [markdown]
# # 08. Model Explainability (SHAP)
# Extract global key drivers of attrition and local individual risk factor breakdowns.

# %%
import json
import pandas as pd

with open("../models/v1/metadata.json") as f:
    meta = json.load(f)

print("Top Global Attrition Drivers:")
drivers_df = pd.DataFrame(meta["top_global_drivers"], columns=["Feature", "Importance"])
display(drivers_df)

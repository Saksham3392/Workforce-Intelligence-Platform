# %% [markdown]
# # 13. Skill Gap Engine
# Set subtraction logic: Gap = RequiredSkills - EmployeeSkills.

# %%
import pandas as pd

df_emp = pd.read_csv("../data/processed/employee_intelligence.csv")
print("Individual Skill Gap Examples:")
display(df_emp[["Employee_ID", "Dept", "Role", "Skill_Gap"]].head(10))

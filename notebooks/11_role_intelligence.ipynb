# %% [markdown]
# # 11. Role Intelligence
# Role master taxonomy and requirements mapping.

# %%
import pandas as pd

df_role_skills = pd.read_csv("../data/processed/role_skills.csv")
print("Skills per Role Summary:")
display(df_role_skills.groupby("Role")["Skill"].count().to_frame("TotalRequiredSkills"))

# %% [markdown]
# # 16. Unified Employee Intelligence Layer
# Consolidated single source of truth for the dashboard.

# %%
import pandas as pd

df = pd.read_csv("../data/processed/employee_intelligence.csv")
print("Total Workforce Intelligence Records:", len(df))
print(f"Risk Breakdown:\n{df['Risk'].value_counts()}")
display(df.head(10))

# %% [markdown]
# # 15. Upskilling Recommendation Engine
# Map individual skill gaps to curated courses.

# %%
import pandas as pd

df_courses = pd.read_csv("../data/processed/courses.csv")
df_emp = pd.read_csv("../data/processed/employee_intelligence.csv")

print("Curated Courses Catalog:")
display(df_courses)

print("\nSample Personalized Upskilling Recommendations:")
display(df_emp[["Employee_ID", "Name", "Role", "Recommendation"]].head(10))

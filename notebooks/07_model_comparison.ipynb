# %% [markdown]
# # 07. Model Comparison
# Benchmark ML models across Precision, Recall, F1, and ROC-AUC.

# %%
import json
import pandas as pd

with open("../models/v1/metadata.json") as f:
    meta = json.load(f)

comparison_df = pd.DataFrame(meta["all_model_comparison"]).T
print("=== Model Comparison Benchmark ===")
display(comparison_df)

# %% [markdown]
# # 01. Data Understanding
# Inspect all 5 raw datasets, shape, schema, column data types, missingness, and attrition class balance.

# %%
import os
import pandas as pd
import numpy as np

DATA_PATH = "../data/raw"
print("Raw Files:", os.listdir(DATA_PATH))

# %%
df_attrition = pd.read_csv(f"{DATA_PATH}/employee_attrition.csv")
print("Attrition Shape:", df_attrition.shape)
print("\nTarget Balance:")
print(df_attrition['AttritionRisk'].value_counts(normalize=True) * 100)
df_attrition.head()

# %%
df_perf = pd.read_csv(f"{DATA_PATH}/hr_performance_engagement.csv")
print("Performance/Engagement Shape:", df_perf.shape)
df_perf.info()

# %% [markdown]
# # 12. Employee Skills Table
# Examine employee possessed skills distribution.

# %%
import pandas as pd

df_emp_skills = pd.read_csv("../data/processed/employee_skills.csv")
print(f"Total Skill Records: {len(df_emp_skills)}")
print("Average Skills per Employee:", round(len(df_emp_skills) / df_emp_skills["EmployeeID"].nunique(), 1))
display(df_emp_skills.head(10))
